# %%
import numpy as np
import matplotlib.pyplot as plt


x = [10, 20, 40, 80, 160]
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(16,16))

#OneMax
# MRPS
ax = axs[0][0]

# 1X
y1X = [30, 70.8, 228.8, 736, 3123.2]
y1X_sde = [5.657, 15.3936, 56.817, 100.176, 592.683] # standard deviation
# UX
yUX = [19.2, 30.2, 60.4, 92.8, 156.8]
yUX_sde = [3.124, 4.423, 6.053, 12.496, 22.112] # standard deviation

ax.errorbar(x, y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of OneMax')
ax.legend()

# Evaluations
ax = axs[0][1]

# 1X
y1X = [240.86, 847, 3985.44, 19585.3, 124122]
y1X_sde = [45.85, 150.712, 841.961, 2408.62, 20448.6] # standard deviation
# UX
yUX = [134.76, 307.46, 871.48, 1921.2, 4547.2]
yUX_sde = [26.015, 39.393, 82.121, 238.921, 606.285] # standard deviation

ax.errorbar(x, y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of OneMax')
ax.legend()

### Trap5

# MRPS
ax = axs[1][0]

# 1X
y1X = [127.2, 252.8, 966.4 , 2828.8 ]
y1X_sde = [32.683, 40.351, 292.516, 452.367] # standard deviation
# UX
yUX = [403.2, 2918.4]
yUX_sde = [49.986, 597.089] # standard deviation

ax.errorbar([10,20,40,80], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of Trap5')
ax.legend()

# Evaluations
ax = axs[1][1]

# 1X
y1X = [1087.84, 3273.92, 17781.1 , 80012.8]
y1X_sde = [301.255, 507.815, 5025.28, 11456.5] # standard deviation
# UX
yUX = [4488.32, 68917.8]
yUX_sde = [690.1, 13106.7] # standard deviation

ax.errorbar([10,20,40,80], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of Trap5')
ax.legend()

### leadingone

# MRPS
ax = axs[2][0]

# 1X
y1X = [105.6, 499.2, 3046.4]
y1X_sde = [ 20.1752, 38.4, 577.562] # standard deviation
# UX
yUX = [61.2, 168, 723.2, 2278.4]
yUX_sde = [16.1047, 38.0316, 134.4, 312.488] # standard deviation

ax.errorbar([10,20,40], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20,40,80], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('MRPS of leadingone')
ax.legend()

# Evaluations
ax = axs[2][1]

# 1X
y1X = [922.48, 8289.92, 102738 ]
y1X_sde = [173.116, 732.546, 15769.2] # standard deviation
# UX
yUX = [522.04, 2499.36, 19777.3, 114532]
yUX_sde = [133.323,491.545, 3174.15, 14235.4] # standard deviation

ax.errorbar([10,20,40], y1X, yerr=y1X_sde, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20,40,80], yUX, yerr=yUX_sde, uplims=True, lolims=True, label='UX')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.set_title('Evaluation of leadingone')
ax.legend()



plt.show()

fig.savefig('visualize_plot.png', dpi=fig.dpi)
